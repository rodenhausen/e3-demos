# %%
load tap sample.txt
# Out:
# Tap: demo_abstract

# %%
print tap
# Out:
# Coverage:True
# Sibling Disjontness:True
# Regions:mnpw
#
# taxonomy 1 Taxonomy1
# (A B F I)
# (F G H)
# (B C D E)
#
# taxonomy 2 Taxonomy2
# (A B F)
# (F G I)
# (B C E H)
#
# articulation
# 1. [1.A equals 2.A]
# 2. [1.E equals 2.E]
# 3. [1.G equals 2.G]
# 4. [1.H equals 2.H]
# 5. [1.B is_included_in 2.B]
# 6. [1.C 1.D lsum 2.C]
# 7. [1.F overlaps 2.B]
# 8. [1.F overlaps 2.F]

# %%
is unique
# Out:
# No.

# %%
more than 10 worlds
# Out:
# There are less than or equal to 10 worlds. In fact, there are 2. The tap is ambiguous.

# %%
graph worlds
# Out:
# 2 worlds have been produced.

# %%
show history
